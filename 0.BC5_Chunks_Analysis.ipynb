# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# retail = pd.read_csv("MindOverData_RetailChallenge.csv", nrows = 40000000)
# retail

# %%
# for i,chunk in enumerate(pd.read_csv("MindOverData_RetailChallenge.csv", chunksize=10000000)):
#     chunk.to_csv('chunk{}.csv'.format(i), index=False)

# %% [markdown]
# We divided the dataset into 19 chunks, that were converted to csv files.

# %% [markdown]
# **CHUNK 0**

# %%
# retail0 = pd.read_csv("chunk0.csv")
# retail0
# Out:
#         ProductFamily_ID ProductCategory_ID   ProductBrand_ID  \
# 0              Family_16        Category_11  ProductBrand_306
# 1              Family_16        Category_11  ProductBrand_306
# 2              Family_16        Category_11  ProductBrand_306
# 3              Family_16        Category_11  ProductBrand_306
# 4              Family_16        Category_11  ProductBrand_306
# ...                  ...                ...               ...
# 9999995         Family_1       Category_178  ProductBrand_917
# 9999996         Family_1       Category_178  ProductBrand_917
# 9999997         Family_1       Category_178  ProductBrand_917
# 9999998         Family_1       Category_178  ProductBrand_917
# 9999999         Family_1       Category_178  ProductBrand_917
#
#            ProductName_ID ProductPackSKU_ID Point-of-Sale_ID        Date  \
# 0         ProductName_649   ProductSKU_1970            POS_1  2017-03-04
# ...

# %%
# retail0['ProductFamily_ID'] = retail0['ProductFamily_ID'].str.replace('Family_','')

# %%
# retail0['ProductCategory_ID'] = retail0['ProductCategory_ID'].str.replace('Category_','')

# %%
# retail0['ProductBrand_ID'] = retail0['ProductBrand_ID'].str.replace('ProductBrand_','')

# %%
# retail0['ProductName_ID'] = retail0['ProductName_ID'].str.replace('ProductName_','')

# %%
# retail0['ProductPackSKU_ID'] = retail0['ProductPackSKU_ID'].str.replace('ProductSKU_','')

# %%
# retail0['Point-of-Sale_ID'] = retail0['Point-of-Sale_ID'].str.replace('POS_','')

# %%
# retail0['Measures'] = retail0['Measures'].str.replace('Sell-out ','')

# %%
# retail0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    object
#  1   ProductCategory_ID  object
#  2   ProductBrand_ID     object
#  3   ProductName_ID      object
#  4   ProductPackSKU_ID   object
#  5   Point-of-Sale_ID    object
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), object(8)
# memory usage: 686.6+ MB

# %%
# retail0[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']] = retail0[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']].astype(int)

# %%
# retail0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    int32
#  1   ProductCategory_ID  int32
#  2   ProductBrand_ID     int32
#  3   ProductName_ID      int32
#  4   ProductPackSKU_ID   int32
#  5   Point-of-Sale_ID    int32
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), int32(6), object(2)
# memory usage: 457.8+ MB

# %%
# retail0.head()
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                16                  11              306             649
# 1                16                  11              306             649
# 2                16                  11              306             649
# 3                16                  11              306             649
# 4                16                  11              306             649
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date Measures   Value
# 0               1970                 1  2017-03-04    units     2.0
# 1               1970                 1  2017-03-04   values  1540.0
# 2               1970                 1  2016-05-02    units     4.0
# 3               1970                 1  2016-05-02   values  3080.0
# 4               1970                 1  2016-10-24    units     2.0

# %%
# retail0 = retail0.set_index(['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID'])

# %%
# retail0.head(10)
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                16                  11              306             649
# 1                16                  11              306             649
# 2                16                  11              306             649
# 3                16                  11              306             649
# 4                16                  11              306             649
# 5                16                  11              306             649
# 6                16                  11              306             649
# 7                16                  11              306             649
# 8                16                  11              306             649
# 9                16                  11              306             649
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date Measures   Value
# 0               1970                 1  2017-03-04    units     2.0
# ...

# %%
# PIVOT0 = retail0.pivot_table(index=['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID','Point-of-Sale_ID','Date'], columns='Measures', values='Value')

# %%
# PIVOT0.columns.name = None               #remove categories
# PIVOT0 = PIVOT0.reset_index()                #index to columns
# PIVOT0
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999150                21                 170              719
# 4999151                21                 170              719
# 4999152                21                 170              719
# 4999153                21                 170              719
# 4999154                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984                 2  2018-06-21
# ...

# %%
# PIVOT0 = PIVOT0.drop_duplicates()
# PIVOT0.shape
# Out:
# (4999155, 9)

# %%
# PIVOT0.to_csv(r'C:\Users\raque\Desktop\BCwDS\BC5_demand_forecasting\PIVOT0.csv')

# %% [markdown]
# **CHUNK 1**

# %%
# retail1 = pd.read_csv("chunk1.csv")
# retail1
# Out:
#         ProductFamily_ID ProductCategory_ID    ProductBrand_ID  \
# 0               Family_1       Category_178   ProductBrand_917
# 1               Family_1       Category_178   ProductBrand_917
# 2               Family_1       Category_178   ProductBrand_917
# 3               Family_1       Category_178   ProductBrand_917
# 4               Family_1       Category_178   ProductBrand_917
# ...                  ...                ...                ...
# 9999995        Family_12       Category_178  ProductBrand_1229
# 9999996        Family_12       Category_178  ProductBrand_1229
# 9999997        Family_12       Category_178  ProductBrand_1229
# 9999998        Family_12       Category_178  ProductBrand_1229
# 9999999        Family_12       Category_178  ProductBrand_1229
#
#            ProductName_ID ProductPackSKU_ID Point-of-Sale_ID        Date  \
# 0        ProductName_1749   ProductSKU_5299           POS_21  2017-07-07
# ...

# %%
# retail1['ProductFamily_ID'] = retail1['ProductFamily_ID'].str.replace('Family_','')

# %%
# retail1['ProductCategory_ID'] = retail1['ProductCategory_ID'].str.replace('Category_','')

# %%
# retail1['ProductBrand_ID'] = retail1['ProductBrand_ID'].str.replace('ProductBrand_','')

# %%
# retail1['ProductName_ID'] = retail1['ProductName_ID'].str.replace('ProductName_','')

# %%
# retail1['ProductPackSKU_ID'] = retail1['ProductPackSKU_ID'].str.replace('ProductSKU_','')

# %%
# retail1['Point-of-Sale_ID'] = retail1['Point-of-Sale_ID'].str.replace('POS_','')

# %%
# retail1['Measures'] = retail1['Measures'].str.replace('Sell-out ','')

# %%
# retail1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    object
#  1   ProductCategory_ID  object
#  2   ProductBrand_ID     object
#  3   ProductName_ID      object
#  4   ProductPackSKU_ID   object
#  5   Point-of-Sale_ID    object
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), object(8)
# memory usage: 686.6+ MB

# %%
# retail1[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']] = retail1[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']].astype(int)

# %%
# retail1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    int32
#  1   ProductCategory_ID  int32
#  2   ProductBrand_ID     int32
#  3   ProductName_ID      int32
#  4   ProductPackSKU_ID   int32
#  5   Point-of-Sale_ID    int32
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), int32(6), object(2)
# memory usage: 457.8+ MB

# %%
# retail1.head()
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                 1                 178              917            1749
# 1                 1                 178              917            1749
# 2                 1                 178              917            1749
# 3                 1                 178              917            1749
# 4                 1                 178              917            1749
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date Measures  Value
# 0               5299                21  2017-07-07    units    1.0
# 1               5299                21  2017-07-08    units    1.0
# 2               5299                21  2017-07-10    units    3.0
# 3               5299                21  2017-07-11    units    2.0
# 4               5299                21  2017-07-13    units    3.0

# %%
# PIVOT1 = retail1.pivot_table(index=['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID','Point-of-Sale_ID','Date'], columns='Measures', values='Value')

# %%
# PIVOT1.columns.name = None               #remove categories
# PIVOT1 = PIVOT1.reset_index()                #index to columns
# PIVOT1
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999351                21                 170              719
# 4999352                21                 170              719
# 4999353                21                 170              719
# 4999354                21                 170              719
# 4999355                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984                21  2016-10-26
# ...

# %%
# PIVOT1 = PIVOT1.drop_duplicates()
# PIVOT1.shape
# Out:
# (4999356, 9)

# %%
# PIVOT1.to_csv(r'C:\Users\raque\Desktop\BCwDS\BC5_demand_forecasting\PIVOT1.csv')

# %% [markdown]
# **CHUNK 2**

# %%
# retail2 = pd.read_csv("chunk2.csv")
# retail2
# Out:
#         ProductFamily_ID ProductCategory_ID    ProductBrand_ID  \
# 0              Family_12       Category_178  ProductBrand_1229
# 1              Family_12       Category_178  ProductBrand_1229
# 2              Family_12       Category_178  ProductBrand_1229
# 3              Family_12       Category_178  ProductBrand_1229
# 4              Family_12       Category_178  ProductBrand_1229
# ...                  ...                ...                ...
# 9999995         Family_1       Category_178   ProductBrand_416
# 9999996         Family_1       Category_178   ProductBrand_416
# 9999997         Family_1       Category_178   ProductBrand_416
# 9999998         Family_1       Category_178   ProductBrand_416
# 9999999         Family_1       Category_178   ProductBrand_416
#
#            ProductName_ID ProductPackSKU_ID Point-of-Sale_ID        Date  \
# 0        ProductName_2324   ProductSKU_7146           POS_41  2016-12-30
# ...

# %%
# retail2['ProductFamily_ID'] = retail2['ProductFamily_ID'].str.replace('Family_','')

# %%
# retail2['ProductCategory_ID'] = retail2['ProductCategory_ID'].str.replace('Category_','')

# %%
# retail2['ProductBrand_ID'] = retail2['ProductBrand_ID'].str.replace('ProductBrand_','')

# %%
# retail2['ProductName_ID'] = retail2['ProductName_ID'].str.replace('ProductName_','')

# %%
# retail2['ProductPackSKU_ID'] = retail2['ProductPackSKU_ID'].str.replace('ProductSKU_','')

# %%
# retail2['Point-of-Sale_ID'] = retail2['Point-of-Sale_ID'].str.replace('POS_','')

# %%
# retail2['Measures'] = retail2['Measures'].str.replace('Sell-out ','')

# %%
# retail2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    object
#  1   ProductCategory_ID  object
#  2   ProductBrand_ID     object
#  3   ProductName_ID      object
#  4   ProductPackSKU_ID   object
#  5   Point-of-Sale_ID    object
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), object(8)
# memory usage: 686.6+ MB

# %%
# retail2[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']] = retail2[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']].astype(int)

# %%
# retail2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    int32
#  1   ProductCategory_ID  int32
#  2   ProductBrand_ID     int32
#  3   ProductName_ID      int32
#  4   ProductPackSKU_ID   int32
#  5   Point-of-Sale_ID    int32
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), int32(6), object(2)
# memory usage: 457.8+ MB

# %%
# retail2.head()
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                12                 178             1229            2324
# 1                12                 178             1229            2324
# 2                12                 178             1229            2324
# 3                12                 178             1229            2324
# 4                12                 178             1229            2324
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date Measures   Value
# 0               7146                41  2016-12-30   values  2004.0
# 1               7146                41  2016-12-31   values   668.0
# 2               7146                41  2017-09-01    units     2.0
# 3               7146                41  2017-09-02    units     1.0
# 4               7146                41  2017-09-05    units     2.0

# %%
# PIVOT2 = retail2.pivot_table(index=['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID','Point-of-Sale_ID','Date'], columns='Measures', values='Value')

# %%
# PIVOT2.columns.name = None               #remove categories
# PIVOT2 = PIVOT2.reset_index()                #index to columns
# PIVOT2
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999500                21                 170              719
# 4999501                21                 170              719
# 4999502                21                 170              719
# 4999503                21                 170              719
# 4999504                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984                41  2017-02-27
# ...

# %%
# PIVOT2 = PIVOT2.drop_duplicates()
# PIVOT2.shape
# Out:
# (4999505, 9)

# %%
# PIVOT2.to_csv(r'C:\Users\raque\Desktop\BCwDS\BC5_demand_forecasting\PIVOT2.csv')

# %% [markdown]
# **CHUNK 3**

# %%
# retail3 = pd.read_csv("chunk3.csv")
# retail3
# Out:
#         ProductFamily_ID ProductCategory_ID   ProductBrand_ID  \
# 0               Family_1       Category_178  ProductBrand_416
# 1               Family_1       Category_178  ProductBrand_416
# 2               Family_1       Category_178  ProductBrand_416
# 3               Family_1       Category_178  ProductBrand_416
# 4               Family_1       Category_178  ProductBrand_416
# ...                  ...                ...               ...
# 9999995        Family_15         Category_2  ProductBrand_435
# 9999996        Family_15         Category_2  ProductBrand_435
# 9999997        Family_15         Category_2  ProductBrand_435
# 9999998        Family_15         Category_2  ProductBrand_435
# 9999999        Family_15         Category_2  ProductBrand_435
#
#           ProductName_ID ProductPackSKU_ID Point-of-Sale_ID        Date  \
# 0        ProductName_807   ProductSKU_2422           POS_60  2018-11-13
# 1        ProductName_807   ProductSKU_2422           POS_60  2018-11-15
# ...

# %%
# retail3['ProductFamily_ID'] = retail3['ProductFamily_ID'].str.replace('Family_','')

# %%
# retail3['ProductCategory_ID'] = retail3['ProductCategory_ID'].str.replace('Category_','')

# %%
# retail3['ProductBrand_ID'] = retail3['ProductBrand_ID'].str.replace('ProductBrand_','')

# %%
# retail3['ProductName_ID'] = retail3['ProductName_ID'].str.replace('ProductName_','')

# %%
# retail3['ProductPackSKU_ID'] = retail3['ProductPackSKU_ID'].str.replace('ProductSKU_','')

# %%
# retail3['Point-of-Sale_ID'] = retail3['Point-of-Sale_ID'].str.replace('POS_','')

# %%
# retail3['Measures'] = retail3['Measures'].str.replace('Sell-out ','')

# %%
# retail3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    object
#  1   ProductCategory_ID  object
#  2   ProductBrand_ID     object
#  3   ProductName_ID      object
#  4   ProductPackSKU_ID   object
#  5   Point-of-Sale_ID    object
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), object(8)
# memory usage: 686.6+ MB

# %%
# retail3[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']] = retail3[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']].astype(int)

# %%
# retail3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    int32
#  1   ProductCategory_ID  int32
#  2   ProductBrand_ID     int32
#  3   ProductName_ID      int32
#  4   ProductPackSKU_ID   int32
#  5   Point-of-Sale_ID    int32
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), int32(6), object(2)
# memory usage: 457.8+ MB

# %%
# retail3.head()
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                 1                 178              416             807
# 1                 1                 178              416             807
# 2                 1                 178              416             807
# 3                 1                 178              416             807
# 4                 1                 178              416             807
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date Measures   Value
# 0               2422                60  2018-11-13   values  2962.5
# 1               2422                60  2018-11-15   values  7855.0
# 2               2422                60  2017-11-16    units     2.0
# 3               2422                60  2017-11-17    units     3.0
# 4               2422                60  2017-11-19    units     1.0

# %%
# PIVOT3 = retail3.pivot_table(index=['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID','Point-of-Sale_ID','Date'], columns='Measures', values='Value')

# %%
# PIVOT3.columns.name = None               #remove categories
# PIVOT3 = PIVOT3.reset_index()                #index to columns
# PIVOT3
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999311                21                 170              719
# 4999312                21                 170              719
# 4999313                21                 170              719
# 4999314                21                 170              719
# 4999315                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984                60  2018-10-15
# ...

# %%
# PIVOT3 = PIVOT3.drop_duplicates()
# PIVOT3.shape
# Out:
# (4999316, 9)

# %%
# PIVOT3.to_csv(r'C:\Users\raque\Desktop\BCwDS\BC5_demand_forecasting\PIVOT3.csv')

# %% [markdown]
# **CHUNK 4**

# %%
# retail4 = pd.read_csv("chunk4.csv")
# retail4
# Out:
#         ProductFamily_ID ProductCategory_ID   ProductBrand_ID  \
# 0              Family_15         Category_2  ProductBrand_435
# 1              Family_15         Category_2  ProductBrand_435
# 2              Family_15         Category_2  ProductBrand_435
# 3              Family_15         Category_2  ProductBrand_435
# 4              Family_15         Category_2  ProductBrand_435
# ...                  ...                ...               ...
# 9999995        Family_12       Category_178  ProductBrand_380
# 9999996        Family_12       Category_178  ProductBrand_380
# 9999997        Family_12       Category_178  ProductBrand_380
# 9999998        Family_12       Category_178  ProductBrand_380
# 9999999        Family_12       Category_178  ProductBrand_380
#
#           ProductName_ID ProductPackSKU_ID Point-of-Sale_ID        Date  \
# 0        ProductName_862   ProductSKU_2715           POS_79  2016-01-21
# 1        ProductName_862   ProductSKU_2715           POS_79  2016-01-25
# ...

# %%
# retail4['ProductFamily_ID'] = retail4['ProductFamily_ID'].str.replace('Family_','')

# %%
# retail4['ProductCategory_ID'] = retail4['ProductCategory_ID'].str.replace('Category_','')

# %%
# retail4['ProductBrand_ID'] = retail4['ProductBrand_ID'].str.replace('ProductBrand_','')

# %%
# retail4['ProductName_ID'] = retail4['ProductName_ID'].str.replace('ProductName_','')

# %%
# retail4['ProductPackSKU_ID'] = retail4['ProductPackSKU_ID'].str.replace('ProductSKU_','')

# %%
# retail4['Point-of-Sale_ID'] = retail4['Point-of-Sale_ID'].str.replace('POS_','')

# %%
# retail4['Measures'] = retail4['Measures'].str.replace('Sell-out ','')

# %%
# retail4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    object
#  1   ProductCategory_ID  object
#  2   ProductBrand_ID     object
#  3   ProductName_ID      object
#  4   ProductPackSKU_ID   object
#  5   Point-of-Sale_ID    object
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), object(8)
# memory usage: 686.6+ MB

# %%
# retail4[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']] = retail4[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']].astype(int)

# %%
# retail4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    int32
#  1   ProductCategory_ID  int32
#  2   ProductBrand_ID     int32
#  3   ProductName_ID      int32
#  4   ProductPackSKU_ID   int32
#  5   Point-of-Sale_ID    int32
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), int32(6), object(2)
# memory usage: 457.8+ MB

# %%
# retail4.head()
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                15                   2              435             862
# 1                15                   2              435             862
# 2                15                   2              435             862
# 3                15                   2              435             862
# 4                15                   2              435             862
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date Measures   Value
# 0               2715                79  2016-01-21    units     3.0
# 1               2715                79  2016-01-25    units     3.0
# 2               2715                79  2016-01-28    units     2.0
# 3               2715                79  2016-01-30    units     2.0
# 4               2715                79  2016-01-18   values  1120.0

# %%
# PIVOT4 = retail4.pivot_table(index=['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID','Point-of-Sale_ID','Date'], columns='Measures', values='Value')

# %%
# PIVOT4.columns.name = None               #remove categories
# PIVOT4 = PIVOT4.reset_index()                #index to columns
# PIVOT4
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999044                21                 170              719
# 4999045                21                 170              719
# 4999046                21                 170              719
# 4999047                21                 170              719
# 4999048                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984                80  2017-02-17
# ...

# %%
# PIVOT4 = PIVOT4.drop_duplicates()
# PIVOT4.shape
# Out:
# (4999049, 9)

# %%
# PIVOT4.to_csv(r'C:\Users\raque\Desktop\BCwDS\BC5_demand_forecasting\PIVOT4.csv')

# %% [markdown]
# **CHUNK 5**

# %%
# retail5 = pd.read_csv("chunk5.csv")
# retail5
# Out:
#         ProductFamily_ID ProductCategory_ID   ProductBrand_ID  \
# 0              Family_12       Category_178  ProductBrand_380
# 1              Family_12       Category_178  ProductBrand_380
# 2              Family_12       Category_178  ProductBrand_380
# 3              Family_12       Category_178  ProductBrand_380
# 4              Family_12       Category_178  ProductBrand_380
# ...                  ...                ...               ...
# 9999995        Family_12       Category_178  ProductBrand_804
# 9999996        Family_12       Category_178  ProductBrand_804
# 9999997        Family_12       Category_178  ProductBrand_804
# 9999998        Family_12       Category_178  ProductBrand_804
# 9999999        Family_12       Category_178  ProductBrand_804
#
#            ProductName_ID ProductPackSKU_ID Point-of-Sale_ID        Date  \
# 0         ProductName_769   ProductSKU_2315          POS_102  2018-06-13
# ...

# %%
# retail5['ProductFamily_ID'] = retail5['ProductFamily_ID'].str.replace('Family_','')

# %%
# retail5['ProductCategory_ID'] = retail5['ProductCategory_ID'].str.replace('Category_','')

# %%
# retail5['ProductBrand_ID'] = retail5['ProductBrand_ID'].str.replace('ProductBrand_','')

# %%
# retail5['ProductName_ID'] = retail5['ProductName_ID'].str.replace('ProductName_','')

# %%
# retail5['ProductPackSKU_ID'] = retail5['ProductPackSKU_ID'].str.replace('ProductSKU_','')

# %%
# retail5['Point-of-Sale_ID'] = retail5['Point-of-Sale_ID'].str.replace('POS_','')

# %%
# retail5['Measures'] = retail5['Measures'].str.replace('Sell-out ','')

# %%
# retail5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    object
#  1   ProductCategory_ID  object
#  2   ProductBrand_ID     object
#  3   ProductName_ID      object
#  4   ProductPackSKU_ID   object
#  5   Point-of-Sale_ID    object
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), object(8)
# memory usage: 686.6+ MB

# %%
# retail5[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']] = retail5[['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID', 'Point-of-Sale_ID']].astype(int)

# %%
# retail5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000000 entries, 0 to 9999999
# Data columns (total 9 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ProductFamily_ID    int32
#  1   ProductCategory_ID  int32
#  2   ProductBrand_ID     int32
#  3   ProductName_ID      int32
#  4   ProductPackSKU_ID   int32
#  5   Point-of-Sale_ID    int32
#  6   Date                object
#  7   Measures            object
#  8   Value               float64
# dtypes: float64(1), int32(6), object(2)
# memory usage: 457.8+ MB

# %%
# retail5.head()
# Out:
#    ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  ProductName_ID  \
# 0                12                 178              380             769
# 1                12                 178              380             769
# 2                12                 178              380             769
# 3                12                 178              380             769
# 4                12                 178              380             769
#
#    ProductPackSKU_ID  Point-of-Sale_ID        Date Measures   Value
# 0               2315               102  2018-06-13    units     1.0
# 1               2315               102  2018-06-15    units     1.0
# 2               2315               102  2018-06-11   values  1100.0
# 3               2315               102  2018-06-12   values  1100.0
# 4               2315               102  2018-06-13   values  1100.0

# %%
# PIVOT5 = retail5.pivot_table(index=['ProductFamily_ID', 'ProductCategory_ID','ProductBrand_ID','ProductName_ID', 'ProductPackSKU_ID','Point-of-Sale_ID','Date'], columns='Measures', values='Value')

# %%
# PIVOT5.columns.name = None               #remove categories
# PIVOT5 = PIVOT5.reset_index()                #index to columns
# PIVOT5
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999337                21                 170              719
# 4999338                21                 170              719
# 4999339                21                 170              719
# 4999340                21                 170              719
# 4999341                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984               103  2019-10-19
# ...

# %%
# PIVOT5 = PIVOT5.drop_duplicates()
# PIVOT5.shape
# Out:
# (4999342, 9)

# %%
# PIVOT5.to_csv(r'C:\Users\raque\Desktop\BCwDS\BC5_demand_forecasting\PIVOT5.csv')

# %% [markdown]
# **----------------------------------------------------------------------------------------------------------------------------**

# %%
df0 = pd.read_csv("PIVOT0.csv")
df0 = df0.drop(['Unnamed: 0'], axis=1)
df0
# Out:
#          ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0                       1                  33              313
# 1                       1                  33              313
# 2                       1                  33              313
# 3                       1                  33              313
# 4                       1                  33              313
# ...                   ...                 ...              ...
# 4999150                21                 170              719
# 4999151                21                 170              719
# 4999152                21                 170              719
# 4999153                21                 170              719
# 4999154                21                 170              719
#
#          ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID        Date  \
# 0                   657               1984                 2  2018-06-21
# ...

# %%
# df0_products = df0[["ProductFamily_ID", "units", "Date"]]
# df0_products = df0_products.groupby(["Date", "ProductFamily_ID"]).sum()#.plot(kind="line")
# df0_products = df0_products.reset_index()

# %%
# df0_products
# Out:
#              Date  ProductFamily_ID  ProductCategory_ID  ProductBrand_ID  \
# 0      2016-01-01                 1               15519            77143
# 1      2016-01-01                 2                3916            17582
# 2      2016-01-01                 3                 178              540
# 3      2016-01-01                 4                  34              279
# 4      2016-01-01                 5                 534             4311
# ...           ...               ...                 ...              ...
# 27845  2019-11-01                17                 243             2455
# 27846  2019-11-01                18                6475            19228
# 27847  2019-11-01                19                 860             2720
# 27848  2019-11-01                20                  62             1896
# 27849  2019-11-01                21                7413            97164
#
#        ProductName_ID  ProductPackSKU_ID  Point-of-Sale_ID  units    values
# ...

# %%
len(df0['ProductCategory_ID'].unique())
# Out:
# 159

# %%
last6months = df0.loc[df0['Date'] > '2019-05-31']

# %%
len(last6months['ProductCategory_ID'].unique())
# Out:
# 144

# %%
# df0category = pd.Series(df0['ProductCategory_ID'].unique())
# last6monthscategory = pd.Series(last6months['ProductCategory_ID'].unique())

# categorylapsed = df0category[~df0category.isin(last6monthscategory)]
# print(categorylapsed)

# %%
df0category = list(df0['ProductCategory_ID'].unique())
last6monthscategory = list(last6months['ProductCategory_ID'].unique())

categorylapsed = set(df0category) - set(last6monthscategory)
categorylapsed
# Out:
# {6, 25, 30, 41, 66, 72, 80, 89, 99, 131, 136, 141, 150, 159, 174}

# %%
len(categorylapsed)
# Out:
# 15

# %%
df0brand = list(df0['ProductBrand_ID'].unique())
last6monthsbrand = list(last6months['ProductBrand_ID'].unique())

brandlapsed = set(df0brand) - set(last6monthsbrand)
brandlapsed
# Out:
# {30,
#  37,
#  46,
#  56,
#  62,
#  64,
#  65,
#  71,
#  82,
#  85,
#  88,
#  91,
#  93,
#  100,
#  102,
#  108,
#  117,
#  119,
#  135,
#  153,
#  170,
#  171,
#  172,
#  173,
#  175,
#  191,
#  194,
#  197,
#  200,
#  215,
#  216,
#  219,
#  227,
#  229,
#  237,
#  242,
#  247,
#  257,
#  271,
#  273,
#  281,
#  283,
#  304,
#  307,
#  310,
#  328,
#  354,
#  355,
#  362,
#  374,
#  388,
#  399,
#  404,
#  431,
#  433,
#  434,
#  460,
#  463,
#  464,
#  466,
#  476,
#  477,
#  491,
#  500,
#  504,
#  514,
#  518,
#  523,
#  530,
#  539,
#  548,
#  552,
#  562,
#  569,
#  575,
#  579,
#  585,
#  586,
#  590,
#  598,
#  602,
#  612,
#  616,
#  619,
#  628,
#  641,
#  654,
#  658,
#  660,
#  666,
#  669,
#  670,
#  675,
#  680,
#  683,
#  684,
#  694,
#  696,
#  699,
#  720,
#  721,
#  723,
#  739,
#  740,
#  742,
#  743,
#  750,
#  752,
#  767,
#  769,
#  772,
#  774,
#  779,
#  780,
#  807,
#  816,
#  831,
#  832,
#  835,
#  839,
#  846,
#  854,
#  856,
#  864,
#  867,
#  869,
# ...

# %%
len(brandlapsed)
# Out:
# 208

# %%
df0name = list(df0['ProductName_ID'].unique())
last6monthsname = list(last6months['ProductName_ID'].unique())

namelapsed = set(df0name) - set(last6monthsname)
namelapsed
# Out:
# {12,
#  16,
#  20,
#  22,
#  24,
#  30,
#  54,
#  59,
#  69,
#  79,
#  89,
#  98,
#  100,
#  104,
#  108,
#  109,
#  112,
#  115,
#  116,
#  118,
#  119,
#  123,
#  128,
#  129,
#  149,
#  166,
#  168,
#  175,
#  180,
#  183,
#  187,
#  192,
#  194,
#  197,
#  204,
#  206,
#  212,
#  221,
#  223,
#  235,
#  249,
#  258,
#  260,
#  265,
#  266,
#  273,
#  276,
#  283,
#  289,
#  293,
#  298,
#  305,
#  306,
#  309,
#  320,
#  343,
#  344,
#  346,
#  348,
#  369,
#  370,
#  379,
#  381,
#  382,
#  383,
#  387,
#  399,
#  400,
#  412,
#  413,
#  416,
#  417,
#  420,
#  423,
#  425,
#  427,
#  428,
#  450,
#  451,
#  456,
#  463,
#  466,
#  467,
#  484,
#  485,
#  487,
#  497,
#  498,
#  510,
#  516,
#  521,
#  527,
#  530,
#  531,
#  533,
#  542,
#  566,
#  568,
#  569,
#  570,
#  597,
#  598,
#  599,
#  601,
#  617,
#  620,
#  622,
#  628,
#  632,
#  643,
#  647,
#  650,
#  653,
#  655,
#  691,
#  696,
#  716,
#  730,
#  731,
#  732,
#  733,
#  734,
#  740,
#  743,
#  747,
#  752,
# ...

# %%
len(namelapsed)
# Out:
# 470

# %%
df0sku = list(df0['ProductPackSKU_ID'].unique())
last6monthssku = list(last6months['ProductPackSKU_ID'].unique())

skulapsed = set(df0sku) - set(last6monthssku)
skulapsed
# Out:
# {8193,
#  3,
#  8197,
#  6,
#  8198,
#  8199,
#  8201,
#  10,
#  12,
#  8204,
#  8205,
#  33,
#  34,
#  8230,
#  39,
#  8231,
#  8232,
#  8234,
#  8239,
#  48,
#  8242,
#  52,
#  8244,
#  8247,
#  8249,
#  61,
#  8253,
#  8255,
#  70,
#  72,
#  8265,
#  74,
#  8272,
#  87,
#  8280,
#  8282,
#  95,
#  96,
#  8290,
#  8295,
#  105,
#  8298,
#  118,
#  8310,
#  8311,
#  8313,
#  8314,
#  8316,
#  131,
#  8330,
#  8331,
#  148,
#  8341,
#  8343,
#  8345,
#  8346,
#  8347,
#  159,
#  174,
#  8375,
#  8376,
#  185,
#  188,
#  8381,
#  8391,
#  206,
#  8407,
#  217,
#  219,
#  8412,
#  223,
#  224,
#  8416,
#  8418,
#  8421,
#  230,
#  231,
#  8424,
#  236,
#  8429,
#  239,
#  244,
#  245,
#  8439,
#  8440,
#  8442,
#  251,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  8450,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  8462,
#  8463,
#  281,
#  8468,
#  8469,
#  8470,
#  8479,
# ...

# %%
len(skulapsed)
# Out:
# 1936

# %%
df0pos = list(df0['Point-of-Sale_ID'].unique())
last6monthspos = list(last6months['Point-of-Sale_ID'].unique())

poslapsed = set(df0pos) - set(last6monthspos)
poslapsed
# Out:
# set()

# %%
len(poslapsed)
# Out:
# 0
